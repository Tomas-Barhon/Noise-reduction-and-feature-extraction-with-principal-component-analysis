# %%
import os
os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")  # Report only TF errors by default
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dataset import Dataset
from pipeline import Pipeline
from visualizations import Visualizer
#controling whether tensorflow does recognize GPU
tf.config.get_visible_devices("GPU")
np.random.seed(42)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Inititate processing pipeline
pipeline = Pipeline(crypto_tick = "eth")
#Initiate visualizer
visualizer = Visualizer()

# %%
print("Missing values distribution:")
visualizer.get_missing_columns(data = pipeline.data)
# Out:
# Missing values distribution:
# {'ETH / Addresses, active, count': [1669, '% 38.105'],
#  'ETH / NVT, adjusted, 90d MA': [1767, '% 40.342'],
#  'ETH / NVT, adjusted, free float,  90d MA': [1768, '% 40.365'],
#  'ETH / NVT, adjusted': [1677, '% 38.288'],
#  'ETH / NVT, adjusted, free float': [1677, '% 38.288'],
#  'ETH / Flow, in, to exchanges, USD': [1678, '% 38.311'],
#  'ETH / Flow, out, from exchanges, USD': [1678, '% 38.311'],
#  'ETH / Fees, transaction, mean, USD': [1678, '% 38.311'],
#  'ETH / Fees, transaction, median, USD': [1678, '% 38.311'],
#  'ETH / Fees, total, USD': [1678, '% 38.311'],
#  'ETH / Miner revenue, USD': [1678, '% 38.311'],
#  'ETH / Capitalization, market, free float, USD': [1678, '% 38.311'],
#  'ETH / Capitalization, realized, USD': [1669, '% 38.105'],
#  'ETH / Capitalization, market, current supply, USD': [1678, '% 38.311'],
#  'ETH / Capitalization, market, estimated supply, USD': [3092, '% 70.594'],
#  'ETH / Volatility, daily returns, 30d': [1708, '% 38.995'],
#  'ETH / Volatility, daily returns, 180d': [1858, '% 42.42'],
#  'ETH / Difficulty, last': [1669, '% 38.105'],
#  'ETH / Difficulty, mean': [1669, '% 38.105'],
#  'ETH / Hash rate, mean': [1776, '% 40.548'],
#  'ETH / Revenue, per hash unit, USD': [1785, '% 40.753'],
#  'ETH / Block, size, mean, bytes': [1669, '% 38.105'],
#  'ETH / Issuance, continuous, percent, daily': [1669, '% 38.105'],
#  'ETH / Network distribution factor': [1669, '% 38.105'],
#  'ETH / Transactions, count': [1669, '% 38.105'],
#  'ETH / Transactions, transfers, count': [1669, '% 38.105'],
#  'ETH / Transactions, transfers, value, mean, USD': [1678, '% 38.311'],
#  'Wiki_eth_search': [1640, '% 37.443'],
#  'Close_^DJI': [1360, '% 31.05'],
#  'Close_^GSPC': [1360, '% 31.05'],
#  'Close_GC=F': [1363, '% 31.119'],
#  'Close_^VIX': [1360, '% 31.05'],
#  'Close_^IXIC': [1360, '% 31.05'],
#  'Close_SMH': [1360, '% 31.05'],
#  'Close_VGT': [1360, '% 31.05'],
#  'Close_XSD': [1360, '% 31.05'],
#  'Close_IYW': [1360, '% 31.05'],
#  'Close_FTEC': [2067, '% 47.192'],
#  'Close_IGV': [1360, '% 31.05'],
#  'Close_QQQ': [1360, '% 31.05'],
#  'Wiki_crypto_search': [1640, '% 37.443'],
#  'USD_EUR_rate': [161, '% 3.676'],
#  'ETH-USD': [1678, '% 38.311']}

# %%
fig = visualizer.draw_missing_data(data = pipeline.data)
fig.show()
# Out:
# /tmp/ipykernel_6061/523243249.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
pipeline.set_beginning(start_date = "2015-08-08")

# %%
fig = visualizer.draw_missing_data(data = pipeline.data)
fig.show()
# Out:
# /tmp/ipykernel_6061/523243249.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
pipeline.preprocess_dataset()

# %%
fig = visualizer.draw_missing_data(data = pipeline.data)
fig.show()
# Out:
# /tmp/ipykernel_6061/523243249.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # Full dimensionality

# %% [markdown]
# ## Full dimensionality - Linear Regression

# %% [markdown]
# ## Full dimensionality - Support Vector Regression

# %% [markdown]
# ## Full dimensionality - LTSM

# %% [markdown]
# # Top 3 principal components

# %% [markdown]
# ## Top 3 principal components - Linear Regression

# %% [markdown]
# ## Top 3 principal components - Support Vector Regression

# %% [markdown]
# ## Top 3 principal components - LSTM

# %% [markdown]
# # Top 5 principal components

# %% [markdown]
# ## Top 5 principal components - Linear Regression

# %% [markdown]
# ## Top 5 principal components - Support Vector Regression

# %% [markdown]
# ## Top 5 principal components - LSTM

# %% [markdown]
# # Top 10 principal components

# %% [markdown]
# ## Top 10 principal components - Linear Regression

# %% [markdown]
# ## Top 10 principal components - Support Vector Regression

# %% [markdown]
# ## Top 10 principal components - LSTM

# %% [markdown]
# # Retained 90% of variance

# %% [markdown]
# ## Retained 90% of variance - Linear Regression

# %% [markdown]
# ## Retained 90% of variance - Support Vector Regression

# %% [markdown]
# ## Retained 90% of variance - LSTM

# %% [markdown]
# # Retained 95% of variance

# %% [markdown]
# ## Retained 95% of variance - Linear Regression

# %% [markdown]
# ## Retained 95% of variance - Support Vector Regression

# %% [markdown]
# ## Retained 95% of variance - LSTM

# %% [markdown]
# # Retained 98% of variance

# %% [markdown]
# ## Retained 98% of variance - Linear Regression

# %% [markdown]
# ## Retained 98% of variance - Support Vector Regression

# %% [markdown]
# ## Retained 98% of variance - LSTM
